# %% [markdown]
# # Entrega - Atividade 0

# %% [markdown]
# #### Aluno: Matheus Raffaelle Nery Castellucci

# %%
# Tamanhos de matrizes
tamanho = [200, 300, 900, 1300]

# %%
# Tempos coletados ao rodar os diferentes programas
tempo_py = [0.66, ((2.35+2.32+2.42+2.45+2.38)/5), 86.24, 297.84]

tempo_cpp = [0.0793687, 0.260289, 7.82261, 22.4972]

tempo_parel = [0.076083, 0.252622, 7.16009, 25.2324]

# %%
import matplotlib.pyplot as plt
plt.plot(tamanho, tempo_py, label='Python')
plt.plot(tamanho, tempo_cpp, label='C++')
plt.plot(tamanho, tempo_parel, label='Paralelo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Tempo de execução (s)')
plt.title('Tempo de execução por tamanho de matriz')
plt.legend()
plt.show()

# %% [markdown]
# ## Faça uma análise comparativa sobre o impacto do paralelismo no desempenho de acordo com a complexidade do problema.

# %% [markdown]
# Pelo que eu percebi, o parelelismo se mostra justificavel apenas em casos muito mais complexos do que o normal. Nos casos analisados na aula, acredito que o tamanho deles não se justificava o uso de paralelismo, pois o tempo de execução não foi reduzido significativamente.

# %% [markdown]
# ## Comente sobre como você acha que este problema pode ser abordado em um ambiente de HPC.

# %% [markdown]
# O ambiente de HPC sendo um conjunto de vários computadores trabalhando juntos, acredito que o paralelismo não precisaria ser implementado através do código, creio que poderiamos separar cada cluster para fazer um processo/conta/instrução diferente, e depois juntar os resultados. Conversando com o professor sobre essa ideia, apareceu o problema de isso gerar um problema quanto á sincronização de dados, o que poderia ser um problema.
